# %%
from PIL import Image
import os

# %%
def crop(input_path, input_img, chunk_height, chunk_width, save_path):
    input_full = input_path + input_img
    im = Image.open(input_full)
    img_width, img_height = im.size
    
    k = 0
    for i in range(0, img_height, chunk_height):
        for j in range(0, img_width, chunk_width):
            
            box = (j, i, j+chunk_width, i+chunk_height)
            chunk = im.crop(box)
            chunk.save(path + input_img[:-4] + "_" + str(k) + ".png")
            k = k+1

# %%
input_path = 'C:/Users/lan/Documents/repos/inter/code/mwork/berkeley_500/'
input_img = '2018.jpg'
chunk_height = 100
chunk_width = 100
save_path = 'C:/Users/lan/Documents/repos/inter/code/mwork/'
crop(input_path, input_img, chunk_height, chunk_width, save_path)

# %%
Image.open(input_path + input_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=321x481 at 0xBAE110E430>

# %%
i=0; j=300
box = (j, i, j+chunk_width, i+chunk_height)
chunk = im.crop(box)
chunk
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0xBAE11215B0>

# %%
for j in range(0, img_width, chunk_width):
    print(j)
# Out:
# 0
# 100
# 200
# 300
