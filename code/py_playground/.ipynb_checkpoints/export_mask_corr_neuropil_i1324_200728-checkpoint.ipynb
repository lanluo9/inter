# %%
import numpy as np
import scipy.io
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# https://github.com/MouseLand/suite2p/issues/166
# https://suite2p.readthedocs.io/_/downloads/en/latest/pdf/

# %%
STATS_FILENAME = 'D:\Lan_temp\suite2p\plane0_i1324_200728_003/stat.npy'
st = np.load(STATS_FILENAME, allow_pickle=True)
n_rois = st.shape[0]
height = 264; width = 796 # Image size in pixels
mask = np.zeros((n_rois, height, width))

for i in range(n_rois):
    mask[i, st[i]['ypix'], st[i]['xpix']] = st[i]['lam']

# %%
mask.shape # find out why mask is not digital
# Out:
# (2685, 264, 796)

# %%
'lam'.upper()
# Out:
# 'LAM'

# %%
iscell = np.load('D:\Lan_temp\suite2p\plane0_i1324_200728_003/iscell.npy', allow_pickle=True)[:, 0].astype(bool)
iscell.shape
# Out:
# (2685,)

# %%
stat = st
ops_FILENAME = 'D:\Lan_temp\suite2p\plane0_i1324_200728_003/ops.npy'
ops = np.load(ops_FILENAME, allow_pickle=True).item()

im = np.zeros((ops['Ly'], ops['Lx']))

for n in range(0,st.shape[0]):
    ypix = stat[n]['ypix'][~stat[n]['overlap']]
    xpix = stat[n]['xpix'][~stat[n]['overlap']]
    im[ypix,xpix] = n+1
    
plt.figure(figsize=(20,10));
plt.imshow(im)
plt.show()

# %%
plt.figure(figsize=(20,10));
plt.imshow(mask[100])

# %%
mask_all = sum(mask,1)
plt.figure(figsize=(20,10))
plt.imshow(mask_all)

# %%
plt.hist(mask[100]);
plt.xlim([0,0.004]);

# %%
sum(sum(mask[100] > 0.0035))
# Out:
# 64

# %%
i=1
mask[i, st[i]['ypix'], st[i]['xpix']]
# Out:
# array([0.00332807, 0.00419319, 0.00296805, 0.00362532, 0.00615833,
#        0.00762292, 0.00810862, 0.00888546, 0.00652746, 0.0068442 ,
#        0.01194239, 0.01389441, 0.012763  , 0.01156076, 0.00894433,
#        0.00302201, 0.00932135, 0.01540534, 0.0178531 , 0.01733898,
#        0.01720219, 0.01286201, 0.00462462, 0.00370349, 0.01135221,
#        0.01697955, 0.02166846, 0.02515738, 0.02484499, 0.0173627 ,
#        0.00589962, 0.0051672 , 0.01329717, 0.02122185, 0.02954673,
#        0.03463935, 0.03186349, 0.02173899, 0.00768653, 0.00443094,
#        0.01501888, 0.02457776, 0.03808748, 0.04737796, 0.03889605,
#        0.02426093, 0.00757035, 0.00258785, 0.01066073, 0.02312563,
#        0.04116468, 0.05115289, 0.036012  , 0.02012333, 0.0051911 ,
#        0.00459325, 0.01204034, 0.02177342, 0.02381748, 0.01532222,
#        0.00842809, 0.0031379 , 0.00342295, 0.00532092, 0.00477904])

# %%
st[i]['ypix']
# Out:
# array([158, 158, 158, 159, 159, 159, 159, 159, 159, 160, 160, 160, 160,
#        160, 160, 160, 161, 161, 161, 161, 161, 161, 161, 162, 162, 162,
#        162, 162, 162, 162, 162, 163, 163, 163, 163, 163, 163, 163, 163,
#        164, 164, 164, 164, 164, 164, 164, 164, 165, 165, 165, 165, 165,
#        165, 165, 165, 166, 166, 166, 166, 166, 166, 166, 167, 167, 167])

# %%
st[i]['xpix']
# Out:
# array([538, 538, 540, 541, 542, 543, 538, 539, 540, 541, 542, 543, 538,
#        539, 540, 541, 542, 543, 544, 537, 538, 539, 540, 541, 542, 543,
#        544, 545, 546, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547,
#        535, 537, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 537,
#        541, 542, 543, 544, 546])

# %% [markdown]
# # corr matrix

# %%
cd //duhs-user-nc1.dhe.duke.edu/dusom_glickfeldlab/All_Staff/home/lan/Analysis/2P/200728_i1324/200728_i1324_runs-003
# Out:
# \\duhs-user-nc1.dhe.duke.edu\dusom_glickfeldlab\All_Staff\home\lan\Analysis\2P\200728_i1324\200728_i1324_runs-003

# %%
ref = scipy.io.loadmat('200728_i1324_runs-003_TCs_addfake')

# %%
ref_npSub_tc = np.asarray(ref['npSub_tc'])
ref_np_tc = np.asarray(ref['np_tc'])

# %%
ref1 = pd.DataFrame(ref_np_tc)
ref2 = pd.DataFrame(ref_npSub_tc)
corr1 = ref1.corr()
corr2 = ref2.corr() # after np sub

# %%
fig = plt.figure(figsize=[20,5])
plt.subplot(1, 2, 1)
sns.heatmap(corr1)

plt.subplot(1, 2, 2)
sns.heatmap(corr2)
plt.show()

# %%
fig = plt.figure()
plt.subplot(1, 2, 1)
plt.hist(corr1.to_numpy().flatten())
plt.subplot(1, 2, 2)
plt.hist(corr2.to_numpy().flatten())
plt.tight_layout()
plt.show()

# %%
f_original = np.load('D:\Lan_temp\suite2p\plane0_i1324_200728_003\F.npy', allow_pickle=True)
f_neuropils = np.load('D:\Lan_temp\suite2p\plane0_i1324_200728_003\Fneu.npy', allow_pickle=True)

ops['neucoeff'] = 0.7 # default setting
f_cells = f_original - ops['neucoeff'] * f_neuropils

# %%
f_neuron = f_cells[iscell,:]
f_ori = f_original[iscell,:]
f_cells.shape, f_neuron.shape
# Out:
# ((2685, 99999), (1107, 99999))

# %%
f_neuron[::11].shape
# Out:
# (101, 99999)

# %%
s1 = pd.DataFrame(f_ori[::11])
s2 = pd.DataFrame(f_neuron[::11])
corr1s = s1.corr()
corr2s = s2.corr() # after np sub

# %%
fig = plt.figure(figsize=[20,5])
plt.subplot(1, 2, 1)
sns.heatmap(corr1s)

plt.subplot(1, 2, 2)
sns.heatmap(corr2s)
plt.show()

# %%
fig = plt.figure()
plt.subplot(1, 2, 1)
plt.hist(corr1s.to_numpy().flatten())
plt.subplot(1, 2, 2)
plt.hist(corr2s.to_numpy().flatten())
plt.tight_layout()
plt.show()
