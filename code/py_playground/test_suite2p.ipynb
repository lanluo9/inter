# %%
pwd
# Out:
# 'C:\\Users\\lan\\Documents\\repos\\inter\\code\\py_playground'

# %%
cd D:\Lan_temp\suite2p_testdata\suite2p\plane0
# Out:
# D:\Lan_temp\suite2p_testdata\suite2p\plane0

# %%
pwd
# Out:
# 'D:\\Lan_temp\\suite2p_testdata\\suite2p\\plane0'

# %%
ls
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is 0AC1-2FB6
#
#  Directory of D:\Lan_temp\suite2p_testdata\suite2p\plane0
#
# 11/24/2020  04:09 PM    <DIR>          .
# 11/24/2020  04:09 PM    <DIR>          ..
# 11/24/2020  03:49 PM     4,173,248,000 data.bin
# 11/24/2020  03:54 PM        19,472,128 F.npy
# 11/24/2020  04:09 PM       206,260,848 Fall.mat
# 11/24/2020  03:54 PM        19,472,128 Fneu.npy
# 11/27/2020  10:18 AM            19,600 iscell.npy
# 11/24/2020  03:54 PM       196,025,982 ops.npy
# 11/24/2020  03:54 PM        19,472,128 spks.npy
# 11/24/2020  03:53 PM         2,912,226 stat.npy
#                8 File(s)  4,636,883,040 bytes
#                2 Dir(s)  805,336,580,096 bytes free

# %%
import numpy as np

# %%
np.load('ops.npy', allow_pickle=True)
# Out:
# array({'suite2p_version': '0.9.2', 'look_one_level_down': 0.0, 'fast_disk': 'D:/Lan_temp/suite2p_testdata\\suite2p\\plane0', 'delete_bin': False, 'mesoscan': False, 'bruker': False, 'h5py': [], 'h5py_key': 'data', 'save_path0': 'D:/Lan_temp/suite2p_testdata', 'save_folder': 'suite2p', 'subfolders': [], 'move_bin': False, 'nplanes': 1, 'nchannels': 1, 'functional_chan': 1, 'tau': 1.0, 'fs': 10.0, 'force_sktiff': False, 'frames_include': -1, 'multiplane_parallel': 0.0, 'preclassify': 0.0, 'save_mat': False, 'save_NWB': 0.0, 'combined': 1.0, 'aspect': 1.0, 'do_bidiphase': False, 'bidiphase': 0.0, 'bidi_corrected': True, 'do_registration': 1, 'two_step_registration': 0.0, 'keep_movie_raw': False, 'nimg_init': 300, 'batch_size': 500, 'maxregshift': 0.1, 'align_by_chan': 1, 'reg_tif': False, 'reg_tif_chan2': False, 'subpixel': 10, 'smooth_sigma_time': 0.0, 'smooth_sigma': 1.15, 'th_badframes': 1.0, 'pad_fft': False, 'nonrigid': True, 'block_size': (128, 128), 'snr_thresh': 1.2, 'maxregshif
# ...

# %%
from suite2p.registration import register

refImg = register.pick_initial_reference(ops)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-62da86f14ce6> in <module>
#       1 from suite2p.registration import register
#       2
# ----> 3 refImg = register.pick_initial_reference(ops)
#
# c:\users\lan\documents\repos\inter\code\borrowed\suite2p\suite2p\registration\register.py in pick_initial_reference(frames)
#      59
#      60     """
# ---> 61     nimg,Ly,Lx = frames.shape
#      62     frames = np.reshape(frames, (nimg,-1)).astype('float32')
#      63     frames = frames - np.reshape(frames.mean(axis=1), (nimg, 1))
#
# ValueError: not enough values to unpack (expected 3, got 0)

# %%
whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# np         module     <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# ops        ndarray    : 1 elems, type `object`, 8 bytes
# register   module     <module 'suite2p.registra<...>gistration\\register.py'>
