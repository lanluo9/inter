# %% [markdown]
# # setup

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import bokeh.plotting as bpl
import cv2
import glob
import logging
import matplotlib.pyplot as plt
plt.style.use('seaborn-talk')
import numpy as np
import os
import pandas as pd
import pickle
from IPython.display import clear_output
try:
    cv2.setNumThreads(0)
except():
    pass

try:
    if __IPYTHON__:
        # this is used for debugging purposes only. allows to reload classes
        # when changed
        get_ipython().magic('load_ext autoreload')
        get_ipython().magic('autoreload 2')
except NameError:
    pass

import caiman as cm
from caiman.motion_correction import MotionCorrect
from caiman.source_extraction.cnmf import cnmf as cnmf
from caiman.source_extraction.cnmf import params as params
from caiman.utils.utils import download_demo
from caiman.utils.visualization import plot_contours, nb_view_patches, nb_plot_contour
bpl.output_notebook()

logging.basicConfig(format=
                          "%(relativeCreated)12d [%(filename)s:%(funcName)20s():%(lineno)s] [%(process)d] %(message)s",
#                     filename="/tmp/caiman.log",
                    level=logging.INFO)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # files & functions

# %%
def caiman_parameter_set(file_now):
    fr = 30                             # imaging rate in frames per second
    decay_time = 0.8                    # length of a typical transient in seconds
    # revised to account for gcamp6s, ~750 ms decay time in V1 L2/3: https://elifesciences.org/articles/51675
    # decay_time: Length of a typical transient in seconds. decay_time is an approximation of the time scale over which to expect a significant shift in the calcium signal during a transient. It defaults to 0.4, which is appropriate for fast indicators (GCaMP6f), slow indicators might use 1 or even more. However, decay_time does not have to precisely fit the data, approximations are enough.
    # V1 layer 2/3: rise and decay time constants for GCaMP6f are 50-100 ms and 200-300 ms; and for GCaMP6s 150-200 ms and ~750 ms (4-5 APs, Figure 3C). https://elifesciences.org/articles/51675

    # motion correction parameters
    strides = (48, 48)          # start a new patch for pw-rigid motion correction every x pixels
    overlaps = (24, 24)         # overlap between pathes (size of patch strides+overlaps)
    max_shifts = (6,6)          # maximum allowed rigid shifts (in pixels)
    max_deviation_rigid = 3     # maximum shifts deviation allowed for patch with respect to rigid shifts
    pw_rigid = True             # flag for performing non-rigid motion correction

    # parameters for source extraction and deconvolution
    p = 1                       # order of the autoregressive system
    gnb = 2                     # number of global background components
    merge_thr = 0.85            # merging threshold, max correlation allowed
    rf = 15                     # half-size of the patches in pixels. e.g., if rf=25, patches are 50x50
    stride_cnmf = 6             # amount of overlap between the patches in pixels
    K = 4                       # number of components per patch
    gSig = [4, 4]               # expected half size of neurons in pixels 
    # kept 4 according to snipaste pixel measurement
    # adjust cell size bc of zoom change around 2021-09

    method_init = 'greedy_roi'  # initialization method (if analyzing dendritic data using 'sparse_nmf')
    ssub = 1                    # spatial subsampling during initialization
    tsub = 1                    # temporal subsampling during intialization

    # parameters for component evaluation
    min_SNR = 2.0               # signal to noise ratio for accepting a component
    rval_thr = 0.90             # space correlation threshold for accepting a component # adjusted
    rval_lowest = 0.0           # added to eliminate fake overlapping neurons, default -1
    cnn_thr = 0.99              # threshold for CNN based classifier
    cnn_lowest = 0.50           # neurons with cnn probability lower than this value are rejected # adjusted
    
    opts_dict = {'fnames': file_now,
                'fr': fr,
                'decay_time': decay_time,
                'strides': strides,
                'overlaps': overlaps,
                'max_shifts': max_shifts,
                'max_deviation_rigid': max_deviation_rigid,
                'pw_rigid': pw_rigid,
                'p': p,
                'nb': gnb,
                'rf': rf,
                'K': K, 
                'stride': stride_cnmf,
                'method_init': method_init,
                'rolling_sum': True,
                'only_init': True,
                'ssub': ssub,
                'tsub': tsub,
                'merge_thr': merge_thr, 
                'min_SNR': min_SNR,
                'rval_thr': rval_thr,
                'use_cnn': True,
                'min_cnn_thr': cnn_thr,
                'cnn_lowest': cnn_lowest}

    opts = params.CNMFParams(params_dict=opts_dict)
    
    return opts

# %%
# def cluster_start():
#     #%% start a cluster for parallel processing (if a cluster already exists it will be closed and a new session will be opened)
#     if 'dview' in locals():
#         cm.stop_server(dview=dview)
#     c, dview, n_processes = cm.cluster.setup_cluster(
#         backend='local', n_processes=None, single_thread=False)

# %%
def caiman_motion_correct_memmap(mc):
    # %%capture
    #%% Run piecewise-rigid motion correction using NoRMCorre
    mc.motion_correct(save_movie=True)
    m_els = cm.load(mc.fname_tot_els)
    border_to_0 = 0 if mc.border_nan is 'copy' else mc.border_to_0 # maximum shift to be used for trimming against NaNs
    
    #%% MEMORY MAPPING
    fname_new = cm.save_memmap(mc.mmap_file, base_name='memmap_', order='C',
                               border_to_0=border_to_0, dview=dview) # exclude borders
    Yr, dims, T = cm.load_memmap(fname_new)
    images = np.reshape(Yr.T, [T] + list(dims), order='F') #load frames in python format (T x X x Y)
    
    #%% restart cluster to clean up memory
    cm.stop_server(dview=dview)
    c, dview, n_processes = cm.cluster.setup_cluster(
        backend='local', n_processes=None, single_thread=False)
    
    return images, fname_new, c, dview, n_processes

# %%
def caiman_fit(n_processes, opts, dview, images):
    # %%capture
    #%% RUN CNMF ON PATCHES
    # First extract spatial and temporal components on patches and combine them
    # for this step deconvolution is turned off (p=0). If you want to have
    # deconvolution within each patch change params.patch['p_patch'] to a
    # nonzero value
    cnm = cnmf.CNMF(n_processes, params=opts, dview=dview)
    cnm = cnm.fit(images)
    
    return cnm

# %%
def corr_img_save(file_now, images):
    Cn = cm.local_correlations(images.transpose(1,2,0))
    f = open(file_now[:-4] + 'Cn.pckl', 'wb')
    pickle.dump(Cn, f)
    f.close()
    
    return Cn

# %%
caiman_data_path = 'C:/Users/ll357/Documents/CaImAn/demos/temp_data/'
tif_files = glob.glob(caiman_data_path + 'i1350_211222/' + "*70k.tif", recursive = True)
tif_files
# Out:
# ['C:/Users/ll357/Documents/CaImAn/demos/temp_data/i1350_211222\\i1350_211222_002_multipage_70k.tif',
#  'C:/Users/ll357/Documents/CaImAn/demos/temp_data/i1350_211222\\i1350_211222_003_multipage_70k.tif',
#  'C:/Users/ll357/Documents/CaImAn/demos/temp_data/i1350_211222\\i1350_211222_004_multipage_70k.tif']

# %% [markdown]
# # run

# %%
# cnm1.fit_file(motion_correct=False, include_eval=True)
# Out:
#     82423360 [cnmf.py:                 fit():470] [41556] (70000, 264, 796)
#     82423360 [cnmf.py:                 fit():487] [41556] Using 63 processes
#     82423360 [cnmf.py:                 fit():498] [41556] using 2070 pixels per process
#     82423360 [cnmf.py:                 fit():499] [41556] using 5000 block_size_spat
#     82423360 [cnmf.py:                 fit():500] [41556] using 5000 block_size_temp
#     82423360 [params.py:                 set():972] [41556] Changing key n_pixels_per_process in group preprocess from 2070 to 225
#     82423366 [params.py:                 set():972] [41556] Changing key n_pixels_per_process in group spatial from 2070 to 225
#     82423391 [map_reduce.py:    run_CNMF_patches():245] [41556] Patch size: (30, 30)
#     85636606 [map_reduce.py:    run_CNMF_patches():264] [41556] Elapsed time for processing patches:                  3213s
#     85636649 [map_reduce.py:    run_CNMF_patches():325] [41556] Embedding patches results into whole FOV
#     85637287 [map_reduce.py:    run_CNMF_patches():417] [41556] Constructing background
#     85637309 [map_reduce.py:    run_CNMF_patches():433] [41556] Compressing background components with a low rank NMF
# C:\Users\ll357\Miniconda3\envs\caiman\lib\site-packages\sklearn\decomposition\_nmf.py:1091: ConvergenceWarning: Maximum number of iterations 100 reached. Increase it to improve convergence.
#   " improve convergence." % max_iter, ConvergenceWarning)
#     85641623 [map_reduce.py:    run_CNMF_patches():498] [41556] Constructing background DONE
#     85642078 [cnmf.py:                 fit():610] [41556] merging
#     85644991 [merging.py:    merge_components():238] [41556] Merging components [237 240 241 369 373]
#     85645451 [merging.py:    merge_components():238] [41556] Merging components [424 428 556 560]
#     85645919 [merging.py:    merge_components():238] [41556] Merging components [1152 1156 1284 1289]
#     85646343 [merging.py:    merge_components():238] [41556] Merging components [102 104 232 236]
#     85646790 [merging.py:    merge_components():238] [41556] Merging components [557 561 688 694]
#     85647233 [merging.py:    merge_components():238] [41556] Merging components [542 544 673 677]
#     85647677 [merging.py:    merge_components():238] [41556] Merging components [1213 1216 1344 1351]
#     85648114 [merging.py:    merge_components():238] [41556] Merging components [ 996 1000 1129 1135]
#     85648562 [merging.py:    merge_components():238] [41556] Merging components [1193 1197 1325 1330]
#     85649007 [merging.py:    merge_components():238] [41556] Merging components [145 148 278 281]
#     85649467 [merging.py:    merge_components():238] [41556] Merging components [1228 1232 1360 1365]
#     85649899 [merging.py:    merge_components():238] [41556] Merging components [400 405 532 539]
#     85650348 [merging.py:    merge_components():238] [41556] Merging components [304 308 439 440]
#     85650795 [merging.py:    merge_components():238] [41556] Merging components [ 95  96 227 229]
#     85651235 [merging.py:    merge_components():238] [41556] Merging components [1262 1266 1392 1396]
#     85651689 [merging.py:    merge_components():238] [41556] Merging components [1050 1052 1183 1184]
#     85652154 [merging.py:    merge_components():238] [41556] Merging components [1314 1316 1446 1449]
#     85652600 [merging.py:    merge_components():238] [41556] Merging components [1300 1305 1433 1438]
#     85653065 [merging.py:    merge_components():238] [41556] Merging components [ 972  977 1104 1108]
#     85653507 [merging.py:    merge_components():238] [41556] Merging components [1065 1068 1199 1202]
#     85653950 [merging.py:    merge_components():238] [41556] Merging components [370 372 502 506]
#     85654432 [merging.py:    merge_components():238] [41556] Merging components [133 137 265 270]
#     85654873 [merging.py:    merge_components():238] [41556] Merging components [139 141 268 274]
#     85655323 [merging.py:    merge_components():238] [41556] Merging components [567 568 696 701]
#     85655774 [merging.py:    merge_components():238] [41556] Merging components [1200 1204 1332 1336]
#     85656226 [merging.py:    merge_components():238] [41556] Merging components [1258 1261 1391 1394]
#     85656677 [merging.py:    merge_components():238] [41556] Merging components [ 36  42 169 174]
#     85657107 [merging.py:    merge_components():238] [41556] Merging components [ 891  894 1022 1027]
#     85657581 [merging.py:    merge_components():238] [41556] Merging components [546 550 676 682]
#     85658040 [merging.py:    merge_components():238] [41556] Merging components [ 60  64 194 196]
#     85658511 [merging.py:    merge_components():238] [41556] Merging components [ 868  872 1001 1007]
#     85658959 [merging.py:    merge_components():238] [41556] Merging components [1238 1240 1369 1373]
#     85659417 [merging.py:    merge_components():238] [41556] Merging components [ 945  950 1077 1082]
#     85659857 [merging.py:    merge_components():238] [41556] Merging components [622 627 754 759]
#     85660279 [merging.py:    merge_components():238] [41556] Merging components [349 353 481 486]
#     85660690 [merging.py:    merge_components():238] [41556] Merging components [702 707 832 836]
#     85661135 [merging.py:    merge_components():238] [41556] Merging components [ 929 1060 1067]
#     85661564 [merging.py:    merge_components():238] [41556] Merging components [161 164 298]
#     85662005 [merging.py:    merge_components():238] [41556] Merging components [1020 1026 1154]
#     85662400 [merging.py:    merge_components():238] [41556] Merging components [ 98 100 233]
#     85662823 [merging.py:    merge_components():238] [41556] Merging components [1056 1062 1188]
#     85663239 [merging.py:    merge_components():238] [41556] Merging components [ 864  997 1002]
#     85663661 [merging.py:    merge_components():238] [41556] Merging components [326 457 463]
#     85664078 [merging.py:    merge_components():238] [41556] Merging components [1233 1237 1368]
#     85664501 [merging.py:    merge_components():238] [41556] Merging components [1286 1291 1417]
#     85664908 [merging.py:    merge_components():238] [41556] Merging components [748 879 880]
#     85665340 [merging.py:    merge_components():238] [41556] Merging components [1206 1210 1338]
#     85665747 [merging.py:    merge_components():238] [41556] Merging components [862 990 993]
#     85666173 [merging.py:    merge_components():238] [41556] Merging components [586 718 721]
#     85666594 [merging.py:    merge_components():238] [41556] Merging components [816 823 948]
#     85667011 [merging.py:    merge_components():238] [41556] Merging components [ 39 165 171]
#     85667422 [merging.py:    merge_components():238] [41556] Merging components [1196 1201 1334]
#     85667849 [merging.py:    merge_components():238] [41556] Merging components [535 662 665]
#     85668263 [merging.py:    merge_components():238] [41556] Merging components [1180 1311 1313]
#     85668688 [merging.py:    merge_components():238] [41556] Merging components [ 19  21 155]
#     85669111 [merging.py:    merge_components():238] [41556] Merging components [563 693 698]
#     85669549 [merging.py:    merge_components():238] [41556] Merging components [638 640 773]
#     85669975 [merging.py:    merge_components():238] [41556] Merging components [761 766 895]
#     85670406 [merging.py:    merge_components():238] [41556] Merging components [ 62  66 199]
#     85670856 [merging.py:    merge_components():238] [41556] Merging components [767 769 902]
#     85671259 [merging.py:    merge_components():238] [41556] Merging components [277 408 414]
#     85671686 [merging.py:    merge_components():238] [41556] Merging components [ 24  29 156]
#     85672125 [merging.py:    merge_components():238] [41556] Merging components [ 91 221 224]
#     85672561 [merging.py:    merge_components():238] [41556] Merging components [478 606 610]
#     85672973 [merging.py:    merge_components():238] [41556] Merging components [1296 1302 1435]
#     85673407 [merging.py:    merge_components():238] [41556] Merging components [608 612]
#     85673823 [merging.py:    merge_components():238] [41556] Merging components [484 616]
#     85674269 [merging.py:    merge_components():238] [41556] Merging components [637 770]
#     85674704 [merging.py:    merge_components():238] [41556] Merging components [1209 1341]
#     85675133 [merging.py:    merge_components():238] [41556] Merging components [961 964]
#     85675564 [merging.py:    merge_components():238] [41556] Merging components [1192 1324]
#     85675983 [merging.py:    merge_components():238] [41556] Merging components [1312 1444]
#     85676401 [merging.py:    merge_components():238] [41556] Merging components [69 72]
#     85676810 [merging.py:    merge_components():238] [41556] Merging components [604 611]
#     85677249 [merging.py:    merge_components():238] [41556] Merging components [1224 1356]
#     85677672 [merging.py:    merge_components():238] [41556] Merging components [103 234]
#     85678127 [merging.py:    merge_components():238] [41556] Merging components [932 937]
#     85678574 [merging.py:    merge_components():238] [41556] Merging components [828 960]
#     85678985 [merging.py:    merge_components():238] [41556] Merging components [776 780]
#     85679413 [merging.py:    merge_components():238] [41556] Merging components [341 472]
#     85679850 [merging.py:    merge_components():238] [41556] Merging components [1028 1160]
#     85680275 [merging.py:    merge_components():238] [41556] Merging components [456 460]
#     85680707 [merging.py:    merge_components():238] [41556] Merging components [1226 1230]
#     85681126 [merging.py:    merge_components():238] [41556] Merging components [1256 1388]
#     85681544 [merging.py:    merge_components():238] [41556] Merging components [1260 1265]
#     85681968 [merging.py:    merge_components():238] [41556] Merging components [ 928 1061]
#     85682430 [merging.py:    merge_components():238] [41556] Merging components [404 536]
#     85682883 [merging.py:    merge_components():238] [41556] Merging components [160 293]
#     85683313 [merging.py:    merge_components():238] [41556] Merging components [1130 1134]
#     85683694 [merging.py:    merge_components():238] [41556] Merging components [760 893]
#     85684131 [merging.py:    merge_components():238] [41556] Merging components [195 197]
#     85684540 [merging.py:    merge_components():238] [41556] Merging components [1288 1423]
#     85684956 [merging.py:    merge_components():238] [41556] Merging components [1276 1408]
#     85685378 [merging.py:    merge_components():238] [41556] Merging components [273 276]
#     85685799 [merging.py:    merge_components():238] [41556] Merging components [361 492]
#     85686217 [merging.py:    merge_components():238] [41556] Merging components [834 967]
#     85686647 [merging.py:    merge_components():238] [41556] Merging components [1354 1358]
#     85687057 [merging.py:    merge_components():238] [41556] Merging components [1128 1132]
#     85687452 [merging.py:    merge_components():238] [41556] Merging components [533 664]
#     85687881 [merging.py:    merge_components():238] [41556] Merging components [433 436]
#     85688303 [merging.py:    merge_components():238] [41556] Merging components [230 362]
#     85688726 [merging.py:    merge_components():238] [41556] Merging components [1211 1342]
#     85689174 [merging.py:    merge_components():238] [41556] Merging components [204 336]
#     85689588 [merging.py:    merge_components():238] [41556] Merging components [1205 1339]
#     85689995 [merging.py:    merge_components():238] [41556] Merging components [1309 1440]
#     85690435 [merging.py:    merge_components():238] [41556] Merging components [1346 1350]
#     85690861 [merging.py:    merge_components():238] [41556] Merging components [1422 1425]
#     85691285 [merging.py:    merge_components():238] [41556] Merging components [33 38]
#     85691687 [merging.py:    merge_components():238] [41556] Merging components [1004 1008]
#     85692116 [merging.py:    merge_components():238] [41556] Merging components [1429 1432]
#     85692536 [merging.py:    merge_components():238] [41556] Merging components [188 192]
#     85692960 [merging.py:    merge_components():238] [41556] Merging components [942 947]
#     85693395 [merging.py:    merge_components():238] [41556] Merging components [157 288]
#     85693791 [merging.py:    merge_components():238] [41556] Merging components [1352 1357]
#     85694199 [merging.py:    merge_components():238] [41556] Merging components [ 68 200]
#     85694622 [merging.py:    merge_components():238] [41556] Merging components [420 552]
#     85695086 [merging.py:    merge_components():238] [41556] Merging components [1273 1404]
#     85695484 [merging.py:    merge_components():238] [41556] Merging components [1362 1366]
#     85695935 [merging.py:    merge_components():238] [41556] Merging components [564 697]
#     85696363 [merging.py:    merge_components():238] [41556] Merging components [ 901 1034]
#     85696786 [merging.py:    merge_components():238] [41556] Merging components [352 485]
#     85697240 [merging.py:    merge_components():238] [41556] Merging components [883 885]
#     85697672 [merging.py:    merge_components():238] [41556] Merging components [614 744]
#     85698091 [merging.py:    merge_components():238] [41556] Merging components [1445 1448]
#     85698494 [merging.py:    merge_components():238] [41556] Merging components [716 849]
#     85698935 [merging.py:    merge_components():238] [41556] Merging components [  4 136]
#     85699365 [merging.py:    merge_components():238] [41556] Merging components [302 434]
#     85699773 [merging.py:    merge_components():238] [41556] Merging components [ 892 1024]
#     85700185 [merging.py:    merge_components():238] [41556] Merging components [1280 1413]
#     85700630 [merging.py:    merge_components():238] [41556] Merging components [216 350]
#     85701051 [merging.py:    merge_components():238] [41556] Merging components [363 494]
#     85701475 [merging.py:    merge_components():238] [41556] Merging components [882 884]
#     85701907 [merging.py:    merge_components():238] [41556] Merging components [1412 1416]
#     85702331 [merging.py:    merge_components():238] [41556] Merging components [1147 1148]
#     85702759 [merging.py:    merge_components():238] [41556] Merging components [1297 1430]
#     85703167 [merging.py:    merge_components():238] [41556] Merging components [844 978]
#     85703598 [merging.py:    merge_components():238] [41556] Merging components [1245 1377]
#     85704007 [merging.py:    merge_components():238] [41556] Merging components [1343 1347]
#     85704449 [merging.py:    merge_components():238] [41556] Merging components [1189 1320]
#     85704880 [merging.py:    merge_components():238] [41556] Merging components [225 228]
#     85705299 [merging.py:    merge_components():238] [41556] Merging components [768 772]
#     85705739 [merging.py:    merge_components():238] [41556] Merging components [1214 1219]
#     85706156 [merging.py:    merge_components():238] [41556] Merging components [949 953]
#     85706585 [merging.py:    merge_components():238] [41556] Merging components [1361 1364]
#     85707024 [merging.py:    merge_components():238] [41556] Merging components [13 16]
#     85707444 [merging.py:    merge_components():238] [41556] Merging components [312 316]
#     85707880 [merging.py:    merge_components():238] [41556] Merging components [1009 1140]
#     85708322 [merging.py:    merge_components():238] [41556] Merging components [538 541]
#     85708727 [merging.py:    merge_components():238] [41556] Merging components [750 753]
#     85709143 [merging.py:    merge_components():238] [41556] Merging components [1177 1308]
#     85709565 [merging.py:    merge_components():238] [41556] Merging components [1033 1036]
#     85709989 [merging.py:    merge_components():238] [41556] Merging components [565 569]
#     85710419 [merging.py:    merge_components():238] [41556] Merging components [356 489]
#     85710850 [merging.py:    merge_components():238] [41556] Merging components [863 992]
#     85711289 [merging.py:    merge_components():238] [41556] Merging components [1076 1208]
#     85711703 [merging.py:    merge_components():238] [41556] Merging components [1287 1419]
#     85712130 [merging.py:    merge_components():238] [41556] Merging components [310 441]
#     85712556 [merging.py:    merge_components():238] [41556] Merging components [ 53 184]
#     85712970 [merging.py:    merge_components():238] [41556] Merging components [218 222]
#     85713393 [merging.py:    merge_components():238] [41556] Merging components [88 94]
#     85713813 [merging.py:    merge_components():238] [41556] Merging components [22 25]
#     85714238 [merging.py:    merge_components():238] [41556] Merging components [ 976 1111]
#     85714677 [merging.py:    merge_components():238] [41556] Merging components [442 572]
#     85715095 [merging.py:    merge_components():238] [41556] Merging components [1281 1415]
#     85715493 [merging.py:    merge_components():238] [41556] Merging components [944 951]
#     85715900 [merging.py:    merge_components():238] [41556] Merging components [500 634]
#     85716316 [merging.py:    merge_components():238] [41556] Merging components [576 582]
#     85716730 [merging.py:    merge_components():238] [41556] Merging components [704 837]
#     85717185 [merging.py:    merge_components():238] [41556] Merging components [699 703]
#     85717579 [merging.py:    merge_components():238] [41556] Merging components [476 482]
#     85718017 [merging.py:    merge_components():238] [41556] Merging components [737 742]
#     85718424 [merging.py:    merge_components():238] [41556] Merging components [421 426]
#     85718847 [merging.py:    merge_components():238] [41556] Merging components [548 680]
#     85719254 [merging.py:    merge_components():238] [41556] Merging components [423 554]
#     85719725 [merging.py:    merge_components():238] [41556] Merging components [854 984]
#     85720166 [merging.py:    merge_components():238] [41556] Merging components [437 570]
#     85720595 [merging.py:    merge_components():238] [41556] Merging components [713 845]
#     85721041 [merging.py:    merge_components():238] [41556] Merging components [ 18 150]
#     85721468 [merging.py:    merge_components():238] [41556] Merging components [624 757]
#     85721868 [merging.py:    merge_components():238] [41556] Merging components [1159 1163]
#     85722300 [merging.py:    merge_components():238] [41556] Merging components [344 477]
#     85722736 [merging.py:    merge_components():238] [41556] Merging components [562 566]
#     85723151 [merging.py:    merge_components():238] [41556] Merging components [ 999 1131]
#     85723567 [merging.py:    merge_components():238] [41556] Merging components [1005 1136]
#     85723991 [merging.py:    merge_components():238] [41556] Merging components [877 881]
#     85724413 [merging.py:    merge_components():238] [41556] Merging components [162 294]
#     85724829 [merging.py:    merge_components():238] [41556] Merging components [1215 1345]
#     85725261 [merging.py:    merge_components():238] [41556] Merging components [425 429]
#     85725675 [merging.py:    merge_components():238] [41556] Merging components [1225 1359]
#     85726092 [merging.py:    merge_components():238] [41556] Merging components [333 338]
#     85726565 [merging.py:    merge_components():238] [41556] Merging components [1217 1348]
#     85726982 [merging.py:    merge_components():238] [41556] Merging components [1162 1164]
#     85727405 [merging.py:    merge_components():238] [41556] Merging components [709 840]
#     85727826 [merging.py:    merge_components():238] [41556] Merging components [856 861]
#     85728240 [merging.py:    merge_components():238] [41556] Merging components [708 712]
#     85728694 [merging.py:    merge_components():238] [41556] Merging components [317 320]
#     85729111 [merging.py:    merge_components():238] [41556] Merging components [792 926]
#     85729542 [merging.py:    merge_components():238] [41556] Merging components [504 639]
#     85729974 [merging.py:    merge_components():238] [41556] Merging components [1044 1178]
#     85730391 [merging.py:    merge_components():238] [41556] Merging components [1251 1383]
#     85730817 [merging.py:    merge_components():238] [41556] Merging components [853 857]
#     85731235 [merging.py:    merge_components():238] [41556] Merging components [176 181]
#     85731658 [merging.py:    merge_components():238] [41556] Merging components [ 924 1057]
#     85732097 [merging.py:    merge_components():238] [41556] Merging components [1143 1146]
#     85732505 [merging.py:    merge_components():238] [41556] Merging components [1091 1221]
#     85732928 [merging.py:    merge_components():238] [41556] Merging components [ 26 158]
#     85733360 [merging.py:    merge_components():238] [41556] Merging components [283 412]
#     85733776 [merging.py:    merge_components():238] [41556] Merging components [954 956]
#     85734222 [merging.py:    merge_components():238] [41556] Merging components [1072 1207]
#     85734639 [merging.py:    merge_components():238] [41556] Merging components [903 905]
#     85735079 [merging.py:    merge_components():238] [41556] Merging components [811 813]
#     85735500 [merging.py:    merge_components():238] [41556] Merging components [466 468]
#     85735908 [merging.py:    merge_components():238] [41556] Merging components [1145 1278]
#     85736339 [merging.py:    merge_components():238] [41556] Merging components [ 889 1021]
#     85736739 [merging.py:    merge_components():238] [41556] Merging components [642 644]
#     85737162 [merging.py:    merge_components():238] [41556] Merging components [1190 1321]
#     85737593 [merging.py:    merge_components():238] [41556] Merging components [54 57]
#     85738024 [merging.py:    merge_components():238] [41556] Merging components [632 765]
#     85738453 [merging.py:    merge_components():238] [41556] Merging components [805 808]
#     85738888 [merging.py:    merge_components():238] [41556] Merging components [324 328]
#     85739312 [merging.py:    merge_components():238] [41556] Merging components [596 600]
#     85739717 [merging.py:    merge_components():238] [41556] Merging components [963 966]
#     85740173 [merging.py:    merge_components():238] [41556] Merging components [1304 1437]
#     85740589 [merging.py:    merge_components():238] [41556] Merging components [979 980]
#     85741041 [merging.py:    merge_components():238] [41556] Merging components [ 9 14]
#     85741428 [merging.py:    merge_components():238] [41556] Merging components [730 732]
#     85741873 [merging.py:    merge_components():238] [41556] Merging components [1378 1380]
#     85742290 [merging.py:    merge_components():238] [41556] Merging components [452 459]
#     85742706 [merging.py:    merge_components():238] [41556] Merging components [913 916]
#     85743143 [merging.py:    merge_components():238] [41556] Merging components [1098 1100]
#     85743564 [merging.py:    merge_components():238] [41556] Merging components [ 899 1029]
#     85743969 [merging.py:    merge_components():238] [41556] Merging components [620 755]
#     85744422 [merging.py:    merge_components():238] [41556] Merging components [488 623]
#     85744857 [merging.py:    merge_components():238] [41556] Merging components [601 605]
#     85745270 [merging.py:    merge_components():238] [41556] Merging components [321 325]
#     85745693 [merging.py:    merge_components():238] [41556] Merging components [1016 1023]
#     85746123 [merging.py:    merge_components():238] [41556] Merging components [733 736]
#     85746542 [merging.py:    merge_components():238] [41556] Merging components [339 342]
#     85746936 [merging.py:    merge_components():238] [41556] Merging components [ 912 1046]
#     85747355 [merging.py:    merge_components():238] [41556] Merging components [1198 1331]
#     85747769 [merging.py:    merge_components():238] [41556] Merging components [ 59 190]
#     85748201 [merging.py:    merge_components():238] [41556] Merging components [746 876]
#     85748625 [merging.py:    merge_components():238] [41556] Merging components [593 598]
#     85749040 [merging.py:    merge_components():238] [41556] Merging components [1259 1389]
#     85749470 [merging.py:    merge_components():238] [41556] Merging components [821 826]
#     85749864 [merging.py:    merge_components():238] [41556] Merging components [1090 1095]
#     85750309 [merging.py:    merge_components():238] [41556] Merging components [985 991]
#     85750725 [merging.py:    merge_components():238] [41556] Merging components [1169 1303]
#     85751157 [merging.py:    merge_components():238] [41556] Merging components [501 505]
#     85751605 [merging.py:    merge_components():238] [41556] Merging components [1133 1137]
#     85752012 [merging.py:    merge_components():238] [41556] Merging components [870 874]
#     85752419 [merging.py:    merge_components():238] [41556] Merging components [226 358]
#     85752838 [merging.py:    merge_components():238] [41556] Merging components [1088 1092]
#     85753296 [merging.py:    merge_components():238] [41556] Merging components [ 887 1017]
#     85753719 [merging.py:    merge_components():238] [41556] Merging components [681 812]
#     85754127 [merging.py:    merge_components():238] [41556] Merging components [ 67 198]
#     85754590 [merging.py:    merge_components():238] [41556] Merging components [313 318]
#     85755024 [merging.py:    merge_components():238] [41556] Merging components [831 833]
#     85755422 [merging.py:    merge_components():238] [41556] Merging components [172 177]
#     85755840 [merging.py:    merge_components():238] [41556] Merging components [1032 1167]
#     85756274 [merging.py:    merge_components():238] [41556] Merging components [904 908]
#     85756700 [merging.py:    merge_components():238] [41556] Merging components [626 628]
#     85757123 [merging.py:    merge_components():238] [41556] Merging components [52 55]
#     85757554 [merging.py:    merge_components():238] [41556] Merging components [295 299]
#     85758003 [merging.py:    merge_components():238] [41556] Merging components [758 888]
#     85758424 [merging.py:    merge_components():238] [41556] Merging components [450 454]
#     85758839 [merging.py:    merge_components():238] [41556] Merging components [952 958]
#     85759299 [merging.py:    merge_components():238] [41556] Merging components [935 939]
#     85759719 [merging.py:    merge_components():238] [41556] Merging components [334 471]
#     85760132 [merging.py:    merge_components():238] [41556] Merging components [860 866]
#     85760548 [merging.py:    merge_components():238] [41556] Merging components [1081 1212]
#     85760980 [merging.py:    merge_components():238] [41556] Merging components [143 275]
#     85761403 [merging.py:    merge_components():238] [41556] Merging components [  8 142]
#     85761834 [merging.py:    merge_components():238] [41556] Merging components [292 296]
#     85762265 [merging.py:    merge_components():238] [41556] Merging components [670 802]
#     85762676 [merging.py:    merge_components():238] [41556] Merging components [1040 1175]
#     85763100 [merging.py:    merge_components():238] [41556] Merging components [264 399]
#     85763506 [merging.py:    merge_components():238] [41556] Merging components [ 27 159]
#     85763905 [merging.py:    merge_components():238] [41556] Merging components [778 782]
#     85764337 [merging.py:    merge_components():238] [41556] Merging components [ 78 208]
#     85764749 [merging.py:    merge_components():238] [41556] Merging components [918 920]
#     85765167 [merging.py:    merge_components():238] [41556] Merging components [537 668]
#     85765573 [merging.py:    merge_components():238] [41556] Merging components [367 371]
#     85765995 [merging.py:    merge_components():238] [41556] Merging components [153 285]
#     85766421 [merging.py:    merge_components():238] [41556] Merging components [1011 1014]
#     85766829 [merging.py:    merge_components():238] [41556] Merging components [107 108]
#     85767259 [merging.py:    merge_components():238] [41556] Merging components [700 835]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\7/ipykernel_41556/2066170254.py in <module>
# ----> 1 cnm1.fit_file(motion_correct=False, include_eval=True)
#       2 print(len(cnm1.estimates.idx_components))
#       3 print(len(cnm1.estimates.idx_components_bad))
#       4 cnm1.estimates.detrend_df_f(quantileMin=8, frames_window=250) # generates cnm.F_dff
#       5
#
# ~\Miniconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py in fit_file(self, motion_correct, indices, include_eval)
#     373             return self.fit(images, indices=indices)
#     374
# --> 375         fit_cnm = self.fit(images, indices=indices)
#     376         Cn = summary_images.local_correlations(images[::max(T//1000, 1)], swap_dim=False)
#     377         Cn[np.isnan(Cn)] = 0
#
# ~\Miniconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py in fit(self, images, indices)
#     648             else:
#     649                 while len(self.estimates.merged_ROIs) > 0:
# --> 650                     self.merge_comps(Yr, mx=np.Inf)
#     651
#     652                 logging.info("update temporal")
#
# ~\Miniconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\cnmf.py in merge_comps(self, Y, mx, fast_merge, max_merge_area)
#     952                              g=self.estimates.g, thr=self.params.get('merging', 'merge_thr'), mx=mx,
#     953                              fast_merge=fast_merge, merge_parallel=self.params.get('merging', 'merge_parallel'),
# --> 954                              max_merge_area=max_merge_area)
#     955
#     956         return self
#
# ~\Miniconda3\envs\caiman\lib\site-packages\caiman\source_extraction\cnmf\merging.py in merge_components(Y, A, b, C, R, f, S, sn_pix, temporal_params, spatial_params, dview, thr, fast_merge, mx, bl, c1, sn, g, merge_parallel, max_merge_area)
#     275             # we continue for the variables
#     276             if S is not None:
# --> 277                 S = np.vstack((S[good_neurons, :], S_merged))
#     278             if R is not None:
#     279                 R = np.vstack((R[good_neurons, :], R_merged))
#
# IndexError: index 1003 is out of bounds for axis 0 with size 999

# %%
# for file_now in tif_files:
#     opts = caiman_parameter_set(file_now)
#     clear_output(wait=True)
#     print(file_now[:-4])
    
    
#     c, dview, n_processes = cm.cluster.setup_cluster(backend='local', n_processes=None, single_thread=False)
#     print('start fitting caiman')
#     mc = MotionCorrect(fnames, dview=dview, **opts.get_group('motion'))

    
# #     cnm1 = cnmf.CNMF(n_processes, params=opts, dview=dview)
# #     cnm1.fit_file(motion_correct=True)
# #     cnm1.fit_file(motion_correct=False, indices=None, include_eval=True)
    
#     corr_img_save(file_now) # images not defined
#     cnm1.estimates.evaluate_components(images, cnm2.params, dview=dview)
#     print(len(cnm1.estimates.idx_components))
#     print(len(cnm1.estimates.idx_components_bad))
#     cnm1.estimates.detrend_df_f(quantileMin=8, frames_window=250) # generates cnm.F_dff
    
#     cnm1.save(file_now[:-4] + '.hdf5')
#     cm.stop_server(dview=dview)
# Out:
# C:/Users/ll357/Documents/CaImAn/demos/temp_data/i1350_211222\i1350_211222_002_multipage_70k
#       204215 [params.py:                 set():972] [41556] Changing key n_processes in group patch from 1 to 63
# start fitting caiman
#       205435 [motion_correction.py:motion_correct_pwrigid():355] [41556] Generating template by rigid motion correction
#       283948 [motion_correction.py:motion_correction_piecewise():3149] [41556] ** Starting parallel motion correction **
#      3649804 [motion_correction.py:motion_correction_piecewise():3157] [41556] ** Finished parallel motion correction **
#      3662449 [motion_correction.py:motion_correction_piecewise():3136] [41556] Saving file as C:/Users/ll357/Documents/CaImAn/demos/temp_data/i1350_211222\i1350_211222_002_multipage_70k_els__d1_264_d2_796_d3_1_order_F_frames_70000_.mmap
#      3662614 [motion_correction.py:motion_correction_piecewise():3149] [41556] ** Starting parallel motion correction **
#     37869285 [motion_correction.py:motion_correction_piecewise():3157] [41556] ** Finished parallel motion correction **
#     38170385 [params.py:                 set():972] [41556] Changing key init_batch in group online from 200 to 70000
#     38170385 [cnmf.py:                 fit():470] [41556] (70000, 264, 796)
#     38170385 [params.py:                 set():972] [41556] Changing key medw in group spatial from None to (3, 3)
#     38170385 [cnmf.py:                 fit():487] [41556] Using 63 processes
#     38170399 [params.py:                 set():972] [41556] Changing key n_pixels_per_process in group preprocess from None to 2070
#     38170399 [params.py:                 set():972] [41556] Changing key n_pixels_per_process in group spatial from None to 2070
#     38170400 [cnmf.py:                 fit():498] [41556] using 2070 pixels per process
#     38170400 [cnmf.py:                 fit():499] [41556] using 5000 block_size_spat
#     38170400 [cnmf.py:                 fit():500] [41556] using 5000 block_size_temp
#     38170401 [params.py:                 set():972] [41556] Changing key n_pixels_per_process in group preprocess from 2070 to 225
#     38170401 [params.py:                 set():972] [41556] Changing key n_pixels_per_process in group spatial from 2070 to 225
#     38170423 [map_reduce.py:    run_CNMF_patches():245] [41556] Patch size: (30, 30)
#     41621919 [map_reduce.py:    run_CNMF_patches():264] [41556] Elapsed time for processing patches:                  3451s
#     41621975 [map_reduce.py:    run_CNMF_patches():325] [41556] Embedding patches results into whole FOV
#     41622612 [map_reduce.py:    run_CNMF_patches():417] [41556] Constructing background
#     41622636 [map_reduce.py:    run_CNMF_patches():433] [41556] Compressing background components with a low rank NMF
# C:\Users\ll357\Miniconda3\envs\caiman\lib\site-packages\sklearn\decomposition\_nmf.py:1091: ConvergenceWarning: Maximum number of iterations 100 reached. Increase it to improve convergence.
#   " improve convergence." % max_iter, ConvergenceWarning)
#     41626950 [map_reduce.py:    run_CNMF_patches():498] [41556] Constructing background DONE
#     41627141 [cnmf.py:                 fit():610] [41556] merging
#     41630028 [merging.py:    merge_components():238] [41556] Merging components [105 106 107 108 109 110 112 113 114 115 116 117]
#     41630522 [merging.py:    merge_components():238] [41556] Merging components [1200 1204 1332 1336]
#     41630972 [merging.py:    merge_components():238] [41556] Merging components [424 428 556 560]
#     41631450 [merging.py:    merge_components():238] [41556] Merging components [ 996 1000 1130 1132]
#     41631921 [merging.py:    merge_components():238] [41556] Merging components [1152 1156 1284 1289]
#     41632359 [merging.py:    merge_components():238] [41556] Merging components [145 149 278 281]
#     41632819 [merging.py:    merge_components():238] [41556] Merging components [557 561 688 694]
#     41633277 [merging.py:    merge_components():238] [41556] Merging components [102 104 232 236]
#     41633723 [merging.py:    merge_components():238] [41556] Merging components [1213 1216 1344 1350]
#     41634176 [merging.py:    merge_components():238] [41556] Merging components [1193 1197 1325 1330]
#     41634635 [merging.py:    merge_components():238] [41556] Merging components [ 61  64 194 196]
#     41635118 [merging.py:    merge_components():238] [41556] Merging components [ 972  976 1104 1108]
#     41635543 [merging.py:    merge_components():238] [41556] Merging components [161 164 295 297]
#     41635987 [merging.py:    merge_components():238] [41556] Merging components [542 544 673 677]
#     41636422 [merging.py:    merge_components():238] [41556] Merging components [1065 1068 1199 1203]
#     41636849 [merging.py:    merge_components():238] [41556] Merging components [400 406 532 539]
#     41637293 [merging.py:    merge_components():238] [41556] Merging components [1262 1266 1392 1396]
#     41637721 [merging.py:    merge_components():238] [41556] Merging components [237 240 369 372]
#     41638176 [merging.py:    merge_components():238] [41556] Merging components [1228 1232 1360 1365]
#     41638597 [merging.py:    merge_components():238] [41556] Merging components [133 137 265 269]
#     41639025 [merging.py:    merge_components():238] [41556] Merging components [ 98 100 231 233]
#     41639453 [merging.py:    merge_components():238] [41556] Merging components [325 330 457 463]
#     41639900 [merging.py:    merge_components():238] [41556] Merging components [1050 1052 1183 1184]
#     41640341 [merging.py:    merge_components():238] [41556] Merging components [ 36  42 169 174]
#     41640793 [merging.py:    merge_components():238] [41556] Merging components [350 355 481 486]
#     41641245 [merging.py:    merge_components():238] [41556] Merging components [734 736 866 870]
#     41641667 [merging.py:    merge_components():238] [41556] Merging components [ 95  96 227 229]
#     41642107 [merging.py:    merge_components():238] [41556] Merging components [1205 1209 1337 1341]
#     41642535 [merging.py:    merge_components():238] [41556] Merging components [567 568 696 701]
#     41642976 [merging.py:    merge_components():238] [41556] Merging components [138 141 268 274]
#     41643422 [merging.py:    merge_components():238] [41556] Merging components [859 862 988 993]
#     41643856 [merging.py:    merge_components():238] [41556] Merging components [304 308 439 440]
#     41644288 [merging.py:    merge_components():238] [41556] Merging components [747 749 878 880]
#     41644732 [merging.py:    merge_components():238] [41556] Merging components [1088 1093 1222 1227]
#     41645176 [merging.py:    merge_components():238] [41556] Merging components [1314 1316 1446 1449]
#     41645608 [merging.py:    merge_components():238] [41556] Merging components [1196 1201 1331 1334]
#     41646041 [merging.py:    merge_components():238] [41556] Merging components [371 374 503 507]
#     41646524 [merging.py:    merge_components():238] [41556] Merging components [ 890  893 1022 1026]
#     41646942 [merging.py:    merge_components():238] [41556] Merging components [823 824 954 956]
#     41647383 [merging.py:    merge_components():238] [41556] Merging components [586 590 717 721]
#     41647796 [merging.py:    merge_components():238] [41556] Merging components [702 704 833 836]
#     41648252 [merging.py:    merge_components():238] [41556] Merging components [1233 1237 1366 1368]
#     41648679 [merging.py:    merge_components():238] [41556] Merging components [1236 1240 1369 1373]
#     41649106 [merging.py:    merge_components():238] [41556] Merging components [ 34  38 165 170]
#     41649534 [merging.py:    merge_components():238] [41556] Merging components [ 945  951 1077 1082]
#     41649952 [merging.py:    merge_components():238] [41556] Merging components [1258 1261 1391 1395]
#     41650400 [merging.py:    merge_components():238] [41556] Merging components [670 672 802 807]
#     41650843 [merging.py:    merge_components():238] [41556] Merging components [1299 1302 1435]
#     41651281 [merging.py:    merge_components():238] [41556] Merging components [ 25 156 162]
#     41651725 [merging.py:    merge_components():238] [41556] Merging components [ 930 1060 1066]
#     41652171 [merging.py:    merge_components():238] [41556] Merging components [1020 1027 1154]
#     41652597 [merging.py:    merge_components():238] [41556] Merging components [ 999 1128 1134]
#     41653043 [merging.py:    merge_components():238] [41556] Merging components [ 864  997 1002]
#     41653475 [merging.py:    merge_components():238] [41556] Merging components [160 290 294]
#     41653929 [merging.py:    merge_components():238] [41556] Merging components [1159 1163 1294]
#     41654331 [merging.py:    merge_components():238] [41556] Merging components [ 91 221 224]
#     41654762 [merging.py:    merge_components():238] [41556] Merging components [ 868  873 1006]
#     41655202 [merging.py:    merge_components():238] [41556] Merging components [354 357 489]
#     41655604 [merging.py:    merge_components():238] [41556] Merging components [742 869 872]
#     41656037 [merging.py:    merge_components():238] [41556] Merging components [1300 1304 1433]
#     41656465 [merging.py:    merge_components():238] [41556] Merging components [1180 1311 1313]
#     41656910 [merging.py:    merge_components():238] [41556] Merging components [1056 1062 1188]
#     41657325 [merging.py:    merge_components():238] [41556] Merging components [ 19  23 153]
#     41657730 [merging.py:    merge_components():238] [41556] Merging components [1286 1291 1416]
#     41658170 [merging.py:    merge_components():238] [41556] Merging components [484 615 616]
#     41658618 [merging.py:    merge_components():238] [41556] Merging components [335 339 471]
#     41659037 [merging.py:    merge_components():238] [41556] Merging components [534 662 665]
#     41659466 [merging.py:    merge_components():238] [41556] Merging components [563 693 697]
#     41659899 [merging.py:    merge_components():238] [41556] Merging components [642 768 772]
#     41660339 [merging.py:    merge_components():238] [41556] Merging components [1135 1136 1269]
#     41660762 [merging.py:    merge_components():238] [41556] Merging components [277 408 414]
#     41661190 [merging.py:    merge_components():238] [41556] Merging components [1271 1273 1404]
#     41661634 [merging.py:    merge_components():238] [41556] Merging components [ 78 206 208]
#     41662053 [merging.py:    merge_components():238] [41556] Merging components [1011 1014 1141]
#     41662468 [merging.py:    merge_components():238] [41556] Merging components [801 934 938]
#     41662897 [merging.py:    merge_components():238] [41556] Merging components [842 969 974]
#     41663326 [merging.py:    merge_components():238] [41556] Merging components [703 705 837]
#     41663762 [merging.py:    merge_components():238] [41556] Merging components [1096 1097 1100]
#     41664206 [merging.py:    merge_components():238] [41556] Merging components [124 128 129]
#     41664650 [merging.py:    merge_components():238] [41556] Merging components [341 472]
#     41665084 [merging.py:    merge_components():238] [41556] Merging components [608 612]
#     41665501 [merging.py:    merge_components():238] [41556] Merging components [292 296]
#     41665955 [merging.py:    merge_components():238] [41556] Merging components [188 192]
#     41666405 [merging.py:    merge_components():238] [41556] Merging components [1280 1414]
#     41666860 [merging.py:    merge_components():238] [41556] Merging components [1224 1356]
#     41667301 [merging.py:    merge_components():238] [41556] Merging components [632 765]
#     41667745 [merging.py:    merge_components():238] [41556] Merging components [404 536]
#     41668159 [merging.py:    merge_components():238] [41556] Merging components [961 964]
#     41668592 [merging.py:    merge_components():238] [41556] Merging components [230 362]
#     41669025 [merging.py:    merge_components():238] [41556] Merging components [ 896 1029]
#     41669470 [merging.py:    merge_components():238] [41556] Merging components [776 780]
#     41669913 [merging.py:    merge_components():238] [41556] Merging components [637 770]
#     41670353 [merging.py:    merge_components():238] [41556] Merging components [157 288]
#     41670778 [merging.py:    merge_components():238] [41556] Merging components [681 812]
#     41671223 [merging.py:    merge_components():238] [41556] Merging components [ 928 1061]
#     41671664 [merging.py:    merge_components():238] [41556] Merging components [604 610]
#     41672086 [merging.py:    merge_components():238] [41556] Merging components [33 37]
#     41672513 [merging.py:    merge_components():238] [41556] Merging components [1192 1324]
#     41672941 [merging.py:    merge_components():238] [41556] Merging components [1312 1444]
#     41673368 [merging.py:    merge_components():238] [41556] Merging components [352 485]
#     41673824 [merging.py:    merge_components():238] [41556] Merging components [103 234]
#     41674269 [merging.py:    merge_components():238] [41556] Merging components [476 482]
#     41674728 [merging.py:    merge_components():238] [41556] Merging components [456 460]
#     41675149 [merging.py:    merge_components():238] [41556] Merging components [1004 1008]
#     41675568 [merging.py:    merge_components():238] [41556] Merging components [828 960]
#     41675992 [merging.py:    merge_components():238] [41556] Merging components [69 72]
#     41676416 [merging.py:    merge_components():238] [41556] Merging components [1009 1140]
#     41676874 [merging.py:    merge_components():238] [41556] Merging components [1260 1265]
#     41677307 [merging.py:    merge_components():238] [41556] Merging components [1256 1388]
#     41677763 [merging.py:    merge_components():238] [41556] Merging components [638 640]
#     41678202 [merging.py:    merge_components():238] [41556] Merging components [195 197]
#     41678649 [merging.py:    merge_components():238] [41556] Merging components [818 948]
#     41679076 [merging.py:    merge_components():238] [41556] Merging components [1032 1166]
#     41679519 [merging.py:    merge_components():238] [41556] Merging components [1225 1230]
#     41679940 [merging.py:    merge_components():238] [41556] Merging components [1129 1133]
#     41680355 [merging.py:    merge_components():238] [41556] Merging components [835 966]
#     41680806 [merging.py:    merge_components():238] [41556] Merging components [422 552]
#     41681235 [merging.py:    merge_components():238] [41556] Merging components [1422 1426]
#     41681666 [merging.py:    merge_components():238] [41556] Merging components [760 894]
#     41682109 [merging.py:    merge_components():238] [41556] Merging components [1352 1357]
#     41682498 [merging.py:    merge_components():238] [41556] Merging components [762 895]
#     41682943 [merging.py:    merge_components():238] [41556] Merging components [361 492]
#     41683372 [merging.py:    merge_components():238] [41556] Merging components [1215 1345]
#     41683783 [merging.py:    merge_components():238] [41556] Merging components [882 884]
#     41684220 [merging.py:    merge_components():238] [41556] Merging components [1028 1160]
#     41684636 [merging.py:    merge_components():238] [41556] Merging components [533 664]
#     41685068 [merging.py:    merge_components():238] [41556] Merging components [1081 1212]
#     41685518 [merging.py:    merge_components():238] [41556] Merging components [1309 1440]
#     41685961 [merging.py:    merge_components():238] [41556] Merging components [418 551]
#     41686389 [merging.py:    merge_components():238] [41556] Merging components [323 327]
#     41686823 [merging.py:    merge_components():238] [41556] Merging components [ 68 200]
#     41687239 [merging.py:    merge_components():238] [41556] Merging components [92 99]
#     41687669 [merging.py:    merge_components():238] [41556] Merging components [1211 1343]
#     41688170 [merging.py:    merge_components():238] [41556] Merging components [1354 1358]
#     41688596 [merging.py:    merge_components():238] [41556] Merging components [1445 1448]
#     41689009 [merging.py:    merge_components():238] [41556] Merging components [433 436]
#     41689451 [merging.py:    merge_components():238] [41556] Merging components [1361 1364]
#     41689902 [merging.py:    merge_components():238] [41556] Merging components [273 276]
#     41690334 [merging.py:    merge_components():238] [41556] Merging components [189 321]
#     41690787 [merging.py:    merge_components():238] [41556] Merging components [1214 1219]
#     41691208 [merging.py:    merge_components():238] [41556] Merging components [1285 1417]
#     41691635 [merging.py:    merge_components():238] [41556] Merging components [614 744]
#     41692075 [merging.py:    merge_components():238] [41556] Merging components [24 28]
#     41692518 [merging.py:    merge_components():238] [41556] Merging components [205 336]
#     41692942 [merging.py:    merge_components():238] [41556] Merging components [1281 1415]
#     41693366 [merging.py:    merge_components():238] [41556] Merging components [844 978]
#     41693805 [merging.py:    merge_components():238] [41556] Merging components [167 298]
#     41694226 [merging.py:    merge_components():238] [41556] Merging components [333 337]
#     41694645 [merging.py:    merge_components():238] [41556] Merging components [820 952]
#     41695075 [merging.py:    merge_components():238] [41556] Merging components [1342 1346]
#     41695521 [merging.py:    merge_components():238] [41556] Merging components [344 477]
#     41695947 [merging.py:    merge_components():238] [41556] Merging components [ 892 1024]
#     41696356 [merging.py:    merge_components():238] [41556] Merging components [154 285]
#     41696783 [merging.py:    merge_components():238] [41556] Merging components [564 698]
#     41697225 [merging.py:    merge_components():238] [41556] Merging components [949 953]
#     41697646 [merging.py:    merge_components():238] [41556] Merging components [1076 1208]
#     41698075 [merging.py:    merge_components():238] [41556] Merging components [218 222]
#     41698500 [merging.py:    merge_components():238] [41556] Merging components [1217 1349]
#     41698926 [merging.py:    merge_components():238] [41556] Merging components [750 753]
#     41699355 [merging.py:    merge_components():238] [41556] Merging components [730 732]
#     41699786 [merging.py:    merge_components():238] [41556] Merging components [363 494]
#     41700218 [merging.py:    merge_components():238] [41556] Merging components [1412 1418]
#     41700634 [merging.py:    merge_components():238] [41556] Merging components [932 937]
#     41701102 [merging.py:    merge_components():238] [41556] Merging components [676 682]
#     41701508 [merging.py:    merge_components():238] [41556] Merging components [ 6 11]
#     41701943 [merging.py:    merge_components():238] [41556] Merging components [ 977 1111]
#     41702372 [merging.py:    merge_components():238] [41556] Merging components [1170 1172]
#     41702834 [merging.py:    merge_components():238] [41556] Merging components [863 992]
#     41703267 [merging.py:    merge_components():238] [41556] Merging components [1146 1148]
#     41703698 [merging.py:    merge_components():238] [41556] Merging components [225 228]
#     41704131 [merging.py:    merge_components():238] [41556] Merging components [144 279]
#     41704556 [merging.py:    merge_components():238] [41556] Merging components [77 81]
#     41704985 [merging.py:    merge_components():238] [41556] Merging components [716 849]
#     41705406 [merging.py:    merge_components():238] [41556] Merging components [216 349]
#     41705824 [merging.py:    merge_components():238] [41556] Merging components [425 429]
#     41706239 [merging.py:    merge_components():238] [41556] Merging components [500 633]
#     41706669 [merging.py:    merge_components():238] [41556] Merging components [1189 1320]
#     41707102 [merging.py:    merge_components():238] [41556] Merging components [1288 1423]
#     41707527 [merging.py:    merge_components():238] [41556] Merging components [1245 1376]
#     41707963 [merging.py:    merge_components():238] [41556] Merging components [538 541]
#     41708391 [merging.py:    merge_components():238] [41556] Merging components [301 434]
#     41708820 [merging.py:    merge_components():238] [41556] Merging components [1005 1137]
#     41709265 [merging.py:    merge_components():238] [41556] Merging components [22 27]
#     41709699 [merging.py:    merge_components():238] [41556] Merging components [  4 136]
#     41710146 [merging.py:    merge_components():238] [41556] Merging components [565 569]
#     41710574 [merging.py:    merge_components():238] [41556] Merging components [13 16]
#     41711007 [merging.py:    merge_components():238] [41556] Merging components [805 808]
#     41711440 [merging.py:    merge_components():238] [41556] Merging components [617 623]
#     41711884 [merging.py:    merge_components():238] [41556] Merging components [548 680]
#     41712313 [merging.py:    merge_components():238] [41556] Merging components [312 316]
#     41712759 [merging.py:    merge_components():238] [41556] Merging components [398 402]
#     41713208 [merging.py:    merge_components():238] [41556] Merging components [283 412]
#     41713624 [merging.py:    merge_components():238] [41556] Merging components [1177 1308]
#     41714048 [merging.py:    merge_components():238] [41556] Merging components [759 888]
#     41714503 [merging.py:    merge_components():238] [41556] Merging components [944 950]
#     41714929 [merging.py:    merge_components():238] [41556] Merging components [310 441]
#     41715355 [merging.py:    merge_components():238] [41556] Merging components [1033 1036]
#     41715785 [merging.py:    merge_components():238] [41556] Merging components [467 469]
#     41716242 [merging.py:    merge_components():238] [41556] Merging components [903 905]
#     41716687 [merging.py:    merge_components():238] [41556] Merging components [874 879]
#     41717120 [merging.py:    merge_components():238] [41556] Merging components [1429 1432]
#     41717539 [merging.py:    merge_components():238] [41556] Merging components [1276 1408]
#     41717967 [merging.py:    merge_components():238] [41556] Merging components [562 566]
#     41718393 [merging.py:    merge_components():238] [41556] Merging components [360 365]
#     41718815 [merging.py:    merge_components():238] [41556] Merging components [ 998 1131]
#     41719248 [merging.py:    merge_components():238] [41556] Merging components [576 582]
#     41719674 [merging.py:    merge_components():238] [41556] Merging components [317 320]
#     41720095 [merging.py:    merge_components():238] [41556] Merging components [ 955 1084]
#     41720524 [merging.py:    merge_components():238] [41556] Merging components [367 496]
#     41720939 [merging.py:    merge_components():238] [41556] Merging components [737 741]
#     41721401 [merging.py:    merge_components():238] [41556] Merging components [713 845]
#     41721828 [merging.py:    merge_components():238] [41556] Merging components [420 426]
#     41722247 [merging.py:    merge_components():238] [41556] Merging components [1268 1402]
#     41722673 [merging.py:    merge_components():238] [41556] Merging components [860 867]
#     41723080 [merging.py:    merge_components():238] [41556] Merging components [176 181]
#     41723509 [merging.py:    merge_components():238] [41556] Merging components [437 570]
#     41723939 [merging.py:    merge_components():238] [41556] Merging components [ 18 150]
#     41724358 [merging.py:    merge_components():238] [41556] Merging components [ 889 1021]
#     41724804 [merging.py:    merge_components():238] [41556] Merging components [442 572]
#     41725233 [merging.py:    merge_components():238] [41556] Merging components [1145 1277]
#     41725666 [merging.py:    merge_components():238] [41556] Merging components [854 984]
#     41726102 [merging.py:    merge_components():238] [41556] Merging components [709 840]
#     41726529 [merging.py:    merge_components():238] [41556] Merging components [54 57]
#     41726956 [merging.py:    merge_components():238] [41556] Merging components [1305 1438]
#     41727391 [merging.py:    merge_components():238] [41556] Merging components [504 639]
#     41727836 [merging.py:    merge_components():238] [41556] Merging components [667 799]
#     41728263 [merging.py:    merge_components():238] [41556] Merging components [ 901 1035]
#     41728690 [merging.py:    merge_components():238] [41556] Merging components [624 757]
#     41729117 [merging.py:    merge_components():238] [41556] Merging components [88 93]
#     41729549 [merging.py:    merge_components():238] [41556] Merging components [1249 1382]
#     41730130 [merging.py:    merge_components():238] [41556] Merging components [324 328]
#     41730553 [merging.py:    merge_components():238] [41556] Merging components [596 600]
#     41730966 [merging.py:    merge_components():238] [41556] Merging components [620 755]
#     41731391 [merging.py:    merge_components():238] [41556] Merging components [1297 1430]
#     41731831 [merging.py:    merge_components():238] [41556] Merging components [537 668]
#     41732242 [merging.py:    merge_components():238] [41556] Merging components [1161 1164]
#     41732670 [merging.py:    merge_components():238] [41556] Merging components [1238 1371]
#     41733099 [merging.py:    merge_components():238] [41556] Merging components [877 881]
#     41733531 [merging.py:    merge_components():238] [41556] Merging components [792 925]
#     41733973 [merging.py:    merge_components():238] [41556] Merging components [1044 1178]
#     41734385 [merging.py:    merge_components():238] [41556] Merging components [856 861]
#     41734807 [merging.py:    merge_components():238] [41556] Merging components [708 712]
#     41735217 [merging.py:    merge_components():238] [41556] Merging components [979 980]
#     41735651 [merging.py:    merge_components():238] [41556] Merging components [700 834]
#     41736074 [merging.py:    merge_components():238] [41556] Merging components [479 480]
#     41736506 [merging.py:    merge_components():238] [41556] Merging components [ 9 14]
#     41736935 [merging.py:    merge_components():238] [41556] Merging components [1296 1428]
#     41737350 [merging.py:    merge_components():238] [41556] Merging components [810 813]
#     41737792 [merging.py:    merge_components():238] [41556] Merging components [904 908]
#     41738223 [merging.py:    merge_components():238] [41556] Merging components [209 212]
#     41738685 [merging.py:    merge_components():238] [41556] Merging components [1169 1303]
#     41739089 [merging.py:    merge_components():238] [41556] Merging components [210 340]
#     41739561 [merging.py:    merge_components():238] [41556] Merging components [1378 1380]
#     41739982 [merging.py:    merge_components():238] [41556] Merging components [413 417]
#     41740412 [merging.py:    merge_components():238] [41556] Merging components [1190 1321]
#     41740849 [merging.py:    merge_components():238] [41556] Merging components [853 858]
#     41741261 [merging.py:    merge_components():238] [41556] Merging components [641 644]
#     41741703 [merging.py:    merge_components():238] [41556] Merging components [602 605]
#     41742116 [merging.py:    merge_components():238] [41556] Merging components [1234 1367]
#     41742557 [merging.py:    merge_components():238] [41556] Merging components [407 409]
#     41742990 [merging.py:    merge_components():238] [41556] Merging components [488 622]
#     41743417 [merging.py:    merge_components():238] [41556] Merging components [ 53 185]
#     41743855 [merging.py:    merge_components():238] [41556] Merging components [957 962]
#     41744295 [merging.py:    merge_components():238] [41556] Merging components [338 342]
#     41744741 [merging.py:    merge_components():238] [41556] Merging components [899 902]
#     41745163 [merging.py:    merge_components():238] [41556] Merging components [1290 1421]
#     41745602 [merging.py:    merge_components():238] [41556] Merging components [593 599]
#     41746023 [merging.py:    merge_components():238] [41556] Merging components [453 459]
#     41746466 [merging.py:    merge_components():238] [41556] Merging components [725 728]
#     41746894 [merging.py:    merge_components():238] [41556] Merging components [733 739]
#     41747303 [merging.py:    merge_components():238] [41556] Merging components [226 358]
#     41747743 [merging.py:    merge_components():238] [41556] Merging components [ 913 1046]
#     41748156 [merging.py:    merge_components():238] [41556] Merging components [1016 1023]
#     41748592 [merging.py:    merge_components():238] [41556] Merging components [559 691]
#     41749020 [merging.py:    merge_components():238] [41556] Merging components [1307 1437]
#     41749443 [merging.py:    merge_components():238] [41556] Merging components [912 916]
#     41749878 [merging.py:    merge_components():238] [41556] Merging components [62 65]
#     41750268 [merging.py:    merge_components():238] [41556] Merging components [767 769]
#     41750714 [merging.py:    merge_components():238] [41556] Merging components [931 933]
#     41751134 [merging.py:    merge_components():238] [41556] Merging components [549 687]
#     41751571 [merging.py:    merge_components():238] [41556] Merging components [ 887 1017]
#     41751991 [merging.py:    merge_components():238] [41556] Merging components [821 826]
#     41752406 [merging.py:    merge_components():238] [41556] Merging components [401 405]
#     41752851 [merging.py:    merge_components():238] [41556] Merging components [1142 1274]
#     41753275 [merging.py:    merge_components():238] [41556] Merging components [201 207]
#     41753693 [merging.py:    merge_components():238] [41556] Merging components [531 660]
#     41754109 [merging.py:    merge_components():238] [41556] Merging components [797 800]
#     41754517 [merging.py:    merge_components():238] [41556] Merging components [625 628]
#     41754964 [merging.py:    merge_components():238] [41556] Merging components [985 991]
#     41755400 [merging.py:    merge_components():238] [41556] Merging components [830 832]
#     41755826 [merging.py:    merge_components():238] [41556] Merging components [213 219]
#     41756259 [merging.py:    merge_components():238] [41556] Merging components [1182 1315]
#     41756671 [merging.py:    merge_components():238] [41556] Merging components [143 275]
#     41757105 [merging.py:    merge_components():238] [41556] Merging components [843 846]
#     41757541 [merging.py:    merge_components():238] [41556] Merging components [264 397]
#     41757964 [merging.py:    merge_components():238] [41556] Merging components [1155 1157]
#     41758398 [merging.py:    merge_components():238] [41556] Merging components [1275 1279]
#     41758828 [merging.py:    merge_components():238] [41556] Merging components [589 595]
#     41759257 [merging.py:    merge_components():238] [41556] Merging components [465 468]
#     41759704 [merging.py:    merge_components():238] [41556] Merging components [1071 1075]
#     41760128 [merging.py:    merge_components():238] [41556] Merging components [415 545]
#     41760559 [merging.py:    merge_components():238] [41556] Merging components [ 59 190]
#     41760987 [merging.py:    merge_components():238] [41556] Merging components [1254 1386]
#     41761396 [merging.py:    merge_components():238] [41556] Merging components [1091 1095]
#     41761816 [merging.py:    merge_components():238] [41556] Merging components [1242 1374]
#     41762267 [merging.py:    merge_components():238] [41556] Merging components [ 907 1038]
#     41762695 [merging.py:    merge_components():238] [41556] Merging components [618 621]
#     41763120 [merging.py:    merge_components():238] [41556] Merging components [373 379]
#     41763523 [merging.py:    merge_components():238] [41556] Merging components [606 611]
#     41763937 [merging.py:    merge_components():238] [41556] Merging components [528 535]
#     41764377 [merging.py:    merge_components():238] [41556] Merging components [918 920]
#     41764811 [merging.py:    merge_components():238] [41556] Merging components [1384 1390]
#     41765234 [merging.py:    merge_components():238] [41556] Merging components [172 177]
#     41765645 [merging.py:    merge_components():238] [41556] Merging components [778 781]
#     41766065 [merging.py:    merge_components():238] [41556] Merging components [1040 1175]
#     41766503 [merging.py:    merge_components():238] [41556] Merging components [501 505]
#     41766907 [merging.py:    merge_components():238] [41556] Merging components [132 135]
#     41769302 [merging.py:    merge_components():238] [41556] Merging components [862 913]
#     41769877 [merging.py:    merge_components():238] [41556] Merging components [766 813]
#     41772333 [merging.py:    merge_components():296] [41556] No more components merged!
#     41772334 [cnmf.py:                 fit():652] [41556] update temporal
#     41772669 [temporal.py:update_temporal_components():207] [41556] Generating residuals
#     41795653 [temporal.py:update_temporal_components():221] [41556] entering the deconvolution
#     41827138 [temporal.py:    update_iteration():391] [41556] 437 out of total 999 temporal components updated
#     41862802 [temporal.py:    update_iteration():391] [41556] 778 out of total 999 temporal components updated
#     41880124 [temporal.py:    update_iteration():391] [41556] 956 out of total 999 temporal components updated
#     41883796 [temporal.py:    update_iteration():391] [41556] 998 out of total 999 temporal components updated
#     41884140 [temporal.py:    update_iteration():391] [41556] 999 out of total 999 temporal components updated
#     41933046 [temporal.py:    update_iteration():391] [41556] 437 out of total 999 temporal components updated
#     41955231 [temporal.py:    update_iteration():391] [41556] 778 out of total 999 temporal components updated
#     41971037 [temporal.py:    update_iteration():391] [41556] 956 out of total 999 temporal components updated
#     41975035 [temporal.py:    update_iteration():391] [41556] 998 out of total 999 temporal components updated
#     41975396 [temporal.py:    update_iteration():391] [41556] 999 out of total 999 temporal components updated
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\7/ipykernel_41556/1392568355.py in <module>
#       9     cnm1.fit_file(motion_correct=True)
#      10
# ---> 11     corr_img_save(file_now)
#      12     print(len(cnm1.estimates.idx_components))
#      13     print(len(cnm1.estimates.idx_components_bad))
#
# ~\AppData\Local\Temp\7/ipykernel_41556/1438705148.py in corr_img_save(file_now)
#       1 def corr_img_save(file_now):
# ----> 2     Cn = cm.local_correlations(images.transpose(1,2,0))
#       3     f = open(file_now[:-4] + 'Cn.pckl', 'wb')
#       4     pickle.dump(Cn, f)
#       5     f.close()
#
# NameError: name 'images' is not defined

# %%
str(type(dview))
# Out:
# "<class 'multiprocessing.pool.Pool'>"

# %%
for file_now in tif_files:
    
    opts = caiman_parameter_set(file_now)
    clear_output(wait=True)
    print('param set')
    print(file_now[:-4])
    
#     cm.stop_server(dview=dview)
#     dview.terminate()
#     c, dview, n_processes = cm.cluster.setup_cluster(backend='local', n_processes=None, single_thread=False)

    try:
        cm.stop_server()
        dview.terminate()
    except:
        print('No clusters to stop')
    c, dview, n_processes = cm.cluster.setup_cluster(
        backend='multiprocessing', n_processes=None, single_thread=False)
    print('cluster started')
    
    mc = MotionCorrect(file_now, dview=dview, **opts.get_group('motion'))
    images, fname_new, c, dview, n_processes = caiman_motion_correct_memmap(mc)
    print('motion corrected')
    
    cnm1 = caiman_fit(n_processes, opts, dview, images)
    print('caiman fitted')
    
    Cn = corr_img_save(file_now, images)
    print('correlation image done')
    cnm1.estimates.evaluate_components(images, cnm2.params, dview=dview)
    print(len(cnm1.estimates.idx_components))
    print(len(cnm1.estimates.idx_components_bad))
    cnm1.estimates.detrend_df_f(quantileMin=8, frames_window=250) # generates cnm.F_dff
    print('dff calculated')
    
    cnm1.save(file_now[:-4] + '.hdf5')
    cm.stop_server(dview=dview)
# Out:
#    171863494 [cluster.py:         stop_server():291] [41556] Stopping cluster...
# param set
# C:/Users/ll357/Documents/CaImAn/demos/temp_data/i1350_211222\i1350_211222_002_multipage_70k
#    171864146 [cluster.py:         stop_server():334] [41556] No cluster to stop...
#    171864147 [cluster.py:         stop_server():348] [41556] stop_cluster(): done
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\7/ipykernel_41556/1270703229.py in <module>
#      16         print('No clusters to stop')
#      17     c, dview, n_processes = cm.cluster.setup_cluster(
# ---> 18         backend='multiprocessing', n_processes=None, single_thread=False)
#      19     print('cluster started')
#      20
#
# ~\Miniconda3\envs\caiman\lib\site-packages\caiman\cluster.py in setup_cluster(backend, n_processes, single_thread, ignore_preexisting, maxtasksperchild)
#     409                 else:
#     410                     raise Exception(
# --> 411                         'A cluster is already runnning. Terminate with dview.terminate() if you want to restart.')
#     412             if (platform.system() == 'Darwin') and (sys.version_info > (3, 0)):
#     413                 try:
#
# Exception: A cluster is already runnning. Terminate with dview.terminate() if you want to restart.
