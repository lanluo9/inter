# %%
from pathlib import Path
from tempfile import TemporaryDirectory

import matplotlib.pyplot as plt
import numpy as np

import suite2p
from suite2p import run_s2p, default_ops
ops = default_ops() # populates ops with the default options
import sys
sys.path.insert(0, 'C:/Users/lan/Documents/repos/suite2p') # option to import from github folder

import matplotlib as mpl
mpl.rcParams.update({
    'axes.spines.left': False,
    'axes.spines.bottom': False,
    'axes.spines.top': False,
    'axes.spines.right': False,
    'legend.frameon': False,
    'figure.subplot.wspace': .01,
    'figure.subplot.hspace': .01,
    'figure.figsize': (18, 13),
    'ytick.major.left': False,
})
jet = mpl.cm.get_cmap('jet')
jet.set_bad(color='k')
# Out:
# C:\Users\lan\anaconda3\envs\suite2p\lib\site-packages\ipykernel_launcher.py:26: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("jet"))

# %%
t = '//duhs-user-nc1.dhe.duke.edu/dusom_glickfeldlab/All_Staff/home/lan/Analysis/2P/200803_i1322/200803_i1322_runs-002/suite2p_ops_20210122\\suite2p\\plane0'
output_op_file = np.load(Path(t).joinpath('ops.npy'), allow_pickle=True).item()

# %%
output_op_file
# Out:
# {'suite2p_version': '0.9.3.dev9+g17501ef',
#  'look_one_level_down': False,
#  'fast_disk': '//duhs-user-nc1.dhe.duke.edu/dusom_glickfeldlab/All_Staff/home/lan/Analysis/2P/200803_i1322/200803_i1322_runs-002/suite2p_ops_20210122\\suite2p\\plane0',
#  'delete_bin': False,
#  'mesoscan': False,
#  'bruker': False,
#  'h5py': '//duhs-user-nc1.dhe.duke.edu/dusom_glickfeldlab/All_Staff/home/lan/Data/2P_images/i1322/200803/002/002_000_000.h5',
#  'h5py_key': ['data'],
#  'save_path0': '//duhs-user-nc1.dhe.duke.edu/dusom_glickfeldlab/All_Staff/home/lan/Analysis/2P/200803_i1322/200803_i1322_runs-002/suite2p_ops_20210122',
#  'save_folder': 'suite2p',
#  'subfolders': [],
#  'move_bin': False,
#  'nplanes': 1,
#  'nchannels': 1,
#  'functional_chan': 1,
#  'tau': 1.375,
#  'fs': 30,
#  'force_sktiff': False,
#  'frames_include': -1,
#  'multiplane_parallel': False,
#  'preclassify': 0.0,
#  'save_mat': False,
#  'save_NWB': False,
#  'combined': True,
#  'aspect': 3.015151515151515,
# ...

# %%
# %store
# Out:
# Stored variables and their in-db values:

# %%
# %store
# Out:
# Stored variables and their in-db values:
# f_cells                    -> array([[448.02353, 428.73416, 500.73618, ..., 554.
# f_neuropils                -> array([[426.99542, 431.33032, 465.34167, ..., 507.
# iscell                     -> array([ True,  True,  True, ..., False, False, Fal
# opsEnd                     -> {'suite2p_version': '0.9.3.dev9+g17501ef', 'look_o
# output_op_file             -> {'suite2p_version': '0.9.3.dev9+g17501ef', 'look_o
# spks                       -> array([[ 0.       ,  0.       ,  0.       , ...,
# stats                      -> array([{'ypix': array([59, 59, 59, 59, 60, 60, 60,
